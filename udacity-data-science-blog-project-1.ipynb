# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/boston/calendar.csv
# /kaggle/input/boston/listings.csv
# /kaggle/input/boston/reviews.csv
# /kaggle/input/seattle/calendar.csv
# /kaggle/input/seattle/listings.csv
# /kaggle/input/seattle/reviews.csv

# %% [markdown]
# #  **Introduction**
#
# I am Aseem Narula, currently pursuing the Nanodegree in Data Science from Udacity,is going to present the project-1 'Write a Data Science Blog Post'.I have used the Kaggle platform to analyze the Seattle and Boston AirBNB homes datasets.In this Jupyter Notebook, I am using the CRISP-DM in my process for finding solutions.
#
# The CRoss Industry Standard Process for Data Mining (CRISP-DM) is a process model with six phases that naturally describes the data science life cycle. It’s like a set of guardrails to help you plan, organize, and implement your data science (or machine learning) project.
#
# 1. Business understanding – What does the business need?
# 2. Data understanding – What data do we have / need? Is it clean?
# 3. Data preparation – How do we organize the data for modeling?
# 4. Modeling – What modeling techniques should we apply?
# 5. Evaluation – Which model best meets the business objectives?
# 6. Deployment – How do stakeholders access the results?

# %% [markdown]
# # Business understanding
# AirBnB Homes are the business in which users can rent out their house properties for the certain period of time in their neighbourhood area at the competitive prices.AirBnb website make sure that the number of properties being booked should be maximize and house owners are charging within the permissible ranges at the same time company make profit based upon the number of bookings happened in a certain area in a particular city.
#
# In our cases, we have downloaded the Boston and Seattle AirBnB homes dataset for our data analysis.
#
#
# #Question-1
# How much AirBNB homes are earning in certain areas ?
#
# #Question-2
# What is the name of the area with the highest average price of the rented home ?
#
# #Question-3
# Compare the rates between the two cities ?
#
# #Question-4
# How many different room tyes are there and which types of rooms are maximum occupied?

# %% [markdown]
# #  Data Understanding
# Analysis of the Seatle and Boston Data Sets.In this section, I have done the initial data analysis of the raw data of the Boston and Seattle AirBnB datasets,I have done the following items to check the raw dataset.
#
# a) Importing & Loading of the Seattle Listings,Reviews,Calendars csv file using pandas
#
# b) Checking the top 5 records
#
# c) Checking the count of the total numbers of records in the dataframe
#
# d) Checking the datatypes of the columns
#
# e) Checking the bottom 5 records using tail() function
#
# f) Checking for the number of unique values in each dataset
#
# g) Checking for the time range for the each of the dataset taken

# %%
#First reviewing all the Seattle Files

# %%
#Importing Seattle Listings File
import pandas as pd
filename = '../input/seattle/listings.csv'
Seattle_Listings = pd.read_csv(filename)
Seattle_Listings.head(5)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
#Couting the total number of records in the Seattle Listing CSV file
Seattle_Listings.count()
# Out:
# id                                  3818
# listing_url                         3818
# scrape_id                           3818
# last_scraped                        3818
# name                                3818
#                                     ...
# cancellation_policy                 3818
# require_guest_profile_picture       3818
# require_guest_phone_verification    3818
# calculated_host_listings_count      3818
# reviews_per_month                   3191
# Length: 92, dtype: int64

# %%
#Seattle Listing dataset list of all the columns 
Seattle_Listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %%
#Seattle_Listings-- This will give us the number of rows and columns
Seattle_Listings.shape
# Out:
# (3818, 92)

# %%
#Checking the bottom 5 records using the tail function
Seattle_Listings.tail(5)
# Out:
#             id                            listing_url       scrape_id  \
# 3813   8101950   https://www.airbnb.com/rooms/8101950  20160104002432
# 3814   8902327   https://www.airbnb.com/rooms/8902327  20160104002432
# 3815  10267360  https://www.airbnb.com/rooms/10267360  20160104002432
# 3816   9604740   https://www.airbnb.com/rooms/9604740  20160104002432
# 3817  10208623  https://www.airbnb.com/rooms/10208623  20160104002432
#
#      last_scraped                                name  \
# 3813   2016-01-04  3BR Mountain View House in Seattle
# 3814   2016-01-04   Portage Bay View!-One Bedroom Apt
# 3815   2016-01-04   Private apartment view of Lake WA
# 3816   2016-01-04   Amazing View with Modern Comfort!
# 3817   2016-01-04           Large Lakefront Apartment
#
#                                                 summary  \
# 3813  Our 3BR/2BA house boasts incredible views of t...
# 3814  800 square foot 1 bedroom basement apartment w...
# ...

# %%
# Checking for the unique values in the dataframe of the Seattle Listings to see 
# if the number of  listings ID's is identical to the calender.csv
print("Total Number of the unique listing ID's -",len(Seattle_Listings.id.unique()))
# Out:
# Total Number of the unique listing ID's - 3818

# %%
#Checking for the time range for the each of the dataset taken
print("First Scrapped timestamp in the dataset---",pd.to_datetime(Seattle_Listings['last_scraped']).min())
print("Last Scrapped timestamp in the dataset---",pd.to_datetime(Seattle_Listings['last_scraped']).max())
# Out:
# First Scrapped timestamp in the dataset--- 2016-01-04 00:00:00
# Last Scrapped timestamp in the dataset--- 2016-01-04 00:00:00

# %%
#Checking Seattle Reviews Files
filename = '../input/seattle/reviews.csv'
Seattle_Reviews = pd.read_csv(filename)
Seattle_Reviews.head(5)
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
#Couting the total number of records in the Seattle Reviews CSV file
Seattle_Reviews.count()
# Out:
# listing_id       84849
# id               84849
# date             84849
# reviewer_id      84849
# reviewer_name    84849
# comments         84831
# dtype: int64

# %%
#Checking the datatypes of the columns in the Seattle Reviews CSV File
Seattle_Reviews.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')

# %%
#Seattle Reviews-- This will give us the number of rows and columns
Seattle_Reviews.shape
# Out:
# (84849, 6)

# %%
#Checking the bottom 5 records using the tail function
Seattle_Reviews.tail(5)
# Out:
#        listing_id        id        date  reviewer_id reviewer_name  \
# 84844     3624990  50436321  2015-10-12     37419458          Ryan
# 84845     3624990  51024875  2015-10-17      6933252         Linda
# 84846     3624990  51511988  2015-10-20     19543701         Jaime
# 84847     3624990  52814482  2015-11-02     24445024        Jørgen
# 84848     9727246  56429621  2015-12-13     30860360     Stephanie
#
#                                                 comments
# 84844  The description and pictures of the apartment ...
# 84845  We had an excellent stay. It was clean and com...
# 84846  Gran ubicación, cerca de todo lo atractivo del...
# 84847  Very good apartement, clean and well sized. Si...
# 84848  Breanne was a great host. Check in was easy, s...

# %%
# Checking for the unique values in the dataframe of the Seattle Reviews to see 
# if the number of  listings ID's is identical to the calender.csv
print("Total Number of the unique listing ID's -",len(Seattle_Reviews.id.unique()))
# Out:
# Total Number of the unique listing ID's - 84849

# %%
#Checking for the time range for the each of the dataset taken
print("First Reviewed timestamp in the dataset---",pd.to_datetime(Seattle_Reviews['date']).min())
print("Last Reviewed timestamp in the dataset---",pd.to_datetime(Seattle_Reviews['date']).max())
# Out:
# First Reviewed timestamp in the dataset--- 2009-06-07 00:00:00
# Last Reviewed timestamp in the dataset--- 2016-01-03 00:00:00

# %%
#Checking the Seattle Calendars file
filename = '../input/seattle/calendar.csv'
Seattle_Calendars = pd.read_csv(filename)
Seattle_Calendars.head(5)
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
#Couting the total number of records in the Seattle Calendars CSV file
Seattle_Calendars.count()
# Out:
# listing_id    1393570
# date          1393570
# available     1393570
# price          934542
# dtype: int64

# %%
#Checking the datatypes of the columns in the Seattle Calendars CSV File
Seattle_Calendars.columns
# Out:
# Index(['listing_id', 'date', 'available', 'price'], dtype='object')

# %%
#Seattle Calendars-- This will give us the number of rows and columns
Seattle_Calendars.shape
# Out:
# (1393570, 4)

# %%
#Checking the bottom 5 records using the tail function
Seattle_Calendars.tail(5)
# Out:
#          listing_id        date available price
# 1393565    10208623  2016-12-29         f   NaN
# 1393566    10208623  2016-12-30         f   NaN
# 1393567    10208623  2016-12-31         f   NaN
# 1393568    10208623  2017-01-01         f   NaN
# 1393569    10208623  2017-01-02         f   NaN

# %%
#Checking for the time range for the each of the dataset taken
print("First date timestamp in the dataset---",pd.to_datetime(Seattle_Calendars['date']).min())
print("Last date timestamp in the dataset---",pd.to_datetime(Seattle_Calendars['date']).max())
# Out:
# First date timestamp in the dataset--- 2016-01-04 00:00:00
# Last date timestamp in the dataset--- 2017-01-02 00:00:00

# %%
#We have analysed the Seattle dataset,now I will be performing the same data functions 
#using the Pandas on the Boston dataset.

# %%
#Importing Boston Listings File
import pandas as pd
filename = '../input/boston/listings.csv'
Boston_Listings = pd.read_csv(filename)
Boston_Listings.head(5)
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# ...

# %%
#Couting the total number of records in the Boston Listing CSV file
Boston_Listings.count()
# Out:
# id                                  3585
# listing_url                         3585
# scrape_id                           3585
# last_scraped                        3585
# name                                3585
#                                     ...
# cancellation_policy                 3585
# require_guest_profile_picture       3585
# require_guest_phone_verification    3585
# calculated_host_listings_count      3585
# reviews_per_month                   2829
# Length: 95, dtype: int64

# %%
#Boston Listings dataset list of all the columns 
Boston_Listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
# ...

# %%
#Boston Listings-- This will give us the number of rows and columns
Boston_Listings.shape
# Out:
# (3585, 95)

# %%
#Checking the bottom 5 records using the tail function
Boston_Listings.tail(5)
# Out:
#             id                            listing_url       scrape_id  \
# 3580   8373729   https://www.airbnb.com/rooms/8373729  20160906204935
# 3581  14844274  https://www.airbnb.com/rooms/14844274  20160906204935
# 3582  14585486  https://www.airbnb.com/rooms/14585486  20160906204935
# 3583  14603878  https://www.airbnb.com/rooms/14603878  20160906204935
# 3584  14504422  https://www.airbnb.com/rooms/14504422  20160906204935
#
#      last_scraped                                   name  \
# 3580   2016-09-07                   Big cozy room near T
# 3581   2016-09-07    BU Apartment DexterPark Bright room
# 3582   2016-09-07               Gorgeous funky apartment
# 3583   2016-09-07  Great Location; Train and Restaurants
# 3584   2016-09-07     (K1) Private Room near Harvard/MIT
#
#                                                 summary  \
# 3580  5 min walking to Orange Line subway with 2 sto...
# 3581  Most popular apartment in BU, best located in ...
# ...

# %%
# Checking for the unique values in the dataframe of the Boston Listings to see 
# if the number of  listings ID's is identical to the calender.csv
print("Total Number of the unique listing ID's -",len(Boston_Listings.id.unique()))
# Out:
# Total Number of the unique listing ID's - 3585

# %%
#Checking for the time range for the each of the dataset taken
print("First Scrapped timestamp in the dataset---",pd.to_datetime(Boston_Listings['last_scraped']).min())
print("Last Scrapped timestamp in the dataset---",pd.to_datetime(Boston_Listings['last_scraped']).max())
# Out:
# First Scrapped timestamp in the dataset--- 2016-09-07 00:00:00
# Last Scrapped timestamp in the dataset--- 2016-09-07 00:00:00

# %%
#Checking Boston Reviews Files
filename = '../input/boston/reviews.csv'
Boston_Reviews = pd.read_csv(filename)
Boston_Reviews.head(5)
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
# Checking for the unique values in the dataframe of the Boston Reviews to see 
# if the number of  listings ID's is identical to the calender.csv
print("Total Number of the unique listing ID's -",len(Boston_Reviews.id.unique()))
# Out:
# Total Number of the unique listing ID's - 68275

# %%
#Checking for the time range for the each of the dataset taken
print("First Reviewed timestamp in the dataset---",pd.to_datetime(Boston_Reviews['date']).min())
print("Last Reviewed timestamp in the dataset---",pd.to_datetime(Boston_Reviews['date']).max())
# Out:
# First Reviewed timestamp in the dataset--- 2009-03-21 00:00:00
# Last Reviewed timestamp in the dataset--- 2016-09-06 00:00:00

# %%
#Checking the Boston Calendars file
filename = '../input/boston/calendar.csv'
Boston_Calendars = pd.read_csv(filename)
Boston_Calendars.head(5)
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %% [markdown]
# # Data Preparation
#
# a) Handling Categorical Data
#
# b) Handling Missing Values
#
# c) Data Cleaning, removing the un-necessary columns from both the datasets

# %%
#Checking for the NaN values in the dataframe in the Seattle Listing Dataset
check_nan_in_df = Seattle_Listings.isnull().sum().head(60)
print (check_nan_in_df)
# Out:
# id                                 0
# listing_url                        0
# scrape_id                          0
# last_scraped                       0
# name                               0
# summary                          177
# space                            569
# description                        0
# experiences_offered                0
# neighborhood_overview           1032
# notes                           1606
# transit                          934
# thumbnail_url                    320
# medium_url                       320
# picture_url                        0
# xl_picture_url                   320
# host_id                            0
# host_url                           0
# host_name                          2
# host_since                         2
# host_location                      8
# host_about                       859
# host_response_time               523
# host_response_rate               523
# host_acceptance_rate             773
# ...

# %%
#Checking for the NaN values in the dataframe in the Seattle Reviews Dataset
check_nan_in_df = Seattle_Reviews.isnull().sum().head(30)
print (check_nan_in_df)
# Out:
# listing_id        0
# id                0
# date              0
# reviewer_id       0
# reviewer_name     0
# comments         18
# dtype: int64

# %%
#Checking for the NaN values in the dataframe in the Seattle Reviews Dataset
check_nan_in_df = Seattle_Calendars.isnull().sum().head(30)
print (check_nan_in_df)
# Out:
# listing_id         0
# date               0
# available          0
# price         459028
# dtype: int64

# %%
#Printing the Seattle Listings neighbourhood column
Seattle_Listings['neighbourhood'].head()
# Out:
# 0    Queen Anne
# 1    Queen Anne
# 2    Queen Anne
# 3    Queen Anne
# 4    Queen Anne
# Name: neighbourhood, dtype: object

# %%
#Printing the Seattle Listings price column
Seattle_Listings['price'].head()
# Out:
# 0     $85.00
# 1    $150.00
# 2    $975.00
# 3    $100.00
# 4    $450.00
# Name: price, dtype: object

# %%
#Total Number of records based on the grouping of the neighbourhood and id 
Seattle_Listings.groupby(['neighbourhood','id']).count()
# Out:
#                         listing_url  scrape_id  last_scraped  name  summary  \
# neighbourhood  id
# Alki           117165             1          1             1     1        0
#                803902             1          1             1     1        0
#                838764             1          1             1     1        0
#                3251016            1          1             1     1        1
#                3265292            1          1             1     1        1
# ...                             ...        ...           ...   ...      ...
# Yesler Terrace 7920539            1          1             1     1        1
#                7956227            1          1             1     1        1
#                8341720            1          1             1     1        1
#                8443258            1          1             1     1        1
#                9317101            1          1             1     1        1
#
# ...

# %%
#Total Number of records based on the grouping of the neighbourhood and id 
Seattle_Listings.groupby(['neighbourhood'])['price'].count().head()
# Out:
# neighbourhood
# Alki              23
# Arbor Heights      3
# Atlantic          50
# Ballard          213
# Belltown         204
# Name: price, dtype: int64

# %%
#Checking the datatype of the price column
Seattle_Listings['price'].dtypes
# Out:
# dtype('O')

# %%
# we use .str to replace and then convert to float
Seattle_Listings['price'] = Seattle_Listings.price.str.replace('$', '')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.

# %%
#Dollar sign is removed but price is datatype is still object 
Seattle_Listings['price'].head()
# Out:
# 0     85.00
# 1    150.00
# 2    975.00
# 3    100.00
# 4    450.00
# Name: price, dtype: object

# %%
#Checking the data type of the price column in the Seattle Listings 
Seattle_Listings['price'].dtypes
# Out:
# dtype('O')

# %%
#Trying to convert the price column to the int data type -- This will give us error
#Seattle_Listings["price"] = Seattle_Listings["price"].astype(int)

# %%
#Removing the decimal values with the empty string
Seattle_Listings['price'] = Seattle_Listings.price.str.replace('.00', '')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
Seattle_Listings['price'].dtypes
#And if you do df.value.astype(float), the error as above will be thrown. Similarly you might also encounter another error as: ValueError: invalid literal for int() with base 10: ” if you try to convert the type to int with df.value.astype(int). So the key is that you have an empty string in the column, and since Python doesn’t know how to convert an empty string to a float, it will throw an error.
# Out:
# dtype('O')

# %%
#Using the to_numeric function to convert the string values to the float64 datatype
pd.to_numeric(Seattle_Listings.price, errors='coerce')
# Out:
# 0        85.0
# 1       150.0
# 2       975.0
# 3         NaN
# 4       450.0
#         ...
# 3813    359.0
# 3814     79.0
# 3815     93.0
# 3816     99.0
# 3817     87.0
# Name: price, Length: 3818, dtype: float64

# %%
Seattle_Listings['price'].head()
# Out:
# 0     85
# 1    150
# 2    975
# 3
# 4    450
# Name: price, dtype: object

# %%
#Converting the Seattle Listings price column to the number using to_numeric function
Seattle_Listings['price'] = pd.to_numeric(Seattle_Listings['price'],errors = 'coerce')

# %%
#Converting the missing values to the zero in the Seattle Dataset
Seattle_Listings['price'] = Seattle_Listings['price'].fillna(0)
Seattle_Listings['price'].head()
# Out:
# 0     85.0
# 1    150.0
# 2    975.0
# 3      0.0
# 4    450.0
# Name: price, dtype: float64

# %% [markdown]
# Data

# %%
#Total Number of records based on the grouping of the neighbourhood having the average price for each Area
Seattle_Listings.groupby(['neighbourhood'])['price'].mean().head()
# Out:
# neighbourhood
# Alki             166.217391
# Arbor Heights     18.000000
# Atlantic         110.280000
# Ballard          114.694836
# Belltown         150.941176
# Name: price, dtype: float64

# %%
#Plotting the graph to find the Area(Neighbourhood) with the highest average price in the Seattle City
import matplotlib.pyplot as plt

df = pd.DataFrame(Seattle_Listings.groupby(['neighbourhood'])['price'].mean().head())
print(df)
# Out:
#                     price
# neighbourhood
# Alki           166.217391
# Arbor Heights   18.000000
# Atlantic       110.280000
# Ballard        114.694836
# Belltown       150.941176

# %%
#Plotting the graph to find the Area(Neighbourhood) with the highest average price in the Seattle City
import matplotlib.pyplot as plt

df = pd.DataFrame(Seattle_Listings.groupby(['neighbourhood_group_cleansed'])['price'].mean())
print(df)
# Out:
#                                    price
# neighbourhood_group_cleansed
# Ballard                       115.986957
# Beacon Hill                    90.432203
# Capitol Hill                  115.425044
# Cascade                       116.505618
# Central Area                  111.265583
# Delridge                       76.949367
# Downtown                      141.009434
# Interbay                      109.727273
# Lake City                      88.194030
# Magnolia                      166.196721
# Northgate                      77.300000
# Other neighborhoods           104.741814
# Queen Anne                    134.850847
# Rainier Valley                 83.094340
# Seward Park                    97.113636
# University District            92.819672
# West Seattle                  125.103448

# %%
#Printing the bar graph
df.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group_cleansed'>

# %% [markdown]
# #Conclusion
#
# The above bar graph clearly displays the neighbourhood with the highest average price for each of the area, our answer is "Magnolia"

# %%
##Importing Boston Listings File
#import pandas as pd
#filename = '../input/boston/listings.csv'
#Boston_Listings = pd.read_csv(filename)
Boston_Listings.head(2)
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
#
#   last_scraped                               name  \
# 0   2016-09-07         Sunny Bungalow in the City
# 1   2016-09-07  Charming room in pet friendly apt
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
#
# ...

# %%
#Checking the datatype of the Boston - price column
Boston_Listings['price'].dtypes
# And if you do df.value.astype(float), the error as above will be thrown.
# Similarly you might also encounter another error as: ValueError: invalid literal for int() with base 10: ” if you try to convert the type to int with df.value.astype(int). So the key is that you have an empty string in the column, 
# and since Python doesn’t know how to convert an empty string to a float, it will throw an error.
# Out:
# dtype('O')

# %%
#Checking the top 5 records of the Boston Listing dataframe after the conversion 
#to the number using to_numeric()
Boston_Listings['price'].head()
# Out:
# 0    $250.00
# 1     $65.00
# 2     $65.00
# 3     $75.00
# 4     $79.00
# Name: price, dtype: object

# %%
#Converting the Seattle Listings price column to the number using to_numeric function
Boston_Listings['price'] = Boston_Listings.price.str.replace('$', '')
Boston_Listings['price'] = pd.to_numeric(Boston_Listings['price'],errors = 'coerce')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.

# %%
#Filling missing values in the Boston Listing dataframe
Boston_Listings['price'] = Boston_Listings['price'].fillna(0)
Boston_Listings['price'].head()
# Out:
# 0    250.0
# 1     65.0
# 2     65.0
# 3     75.0
# 4     79.0
# Name: price, dtype: float64

# %%
#Plotting the graph to find the Area(Neighbourhood) with the highest average price in the Boston City
import matplotlib.pyplot as plt

df = pd.DataFrame(Boston_Listings.groupby(['neighbourhood_cleansed'])['price'].mean())
print(df)
# Out:
#                               price
# neighbourhood_cleansed
# Allston                  112.307692
# Back Bay                 236.811258
# Bay Village              266.833333
# Beacon Hill              211.144330
# Brighton                 118.767568
# Charlestown              189.036036
# Chinatown                232.352113
# Dorchester                91.639405
# Downtown                 236.459302
# East Boston              119.153333
# Fenway                   197.472414
# Hyde Park                 86.548387
# Jamaica Plain            138.478134
# Leather District         253.600000
# Longwood Medical Area    138.444444
# Mattapan                  75.125000
# Mission Hill             121.967742
# North End                195.678322
# Roslindale                98.428571
# Roxbury                  136.611111
# South Boston             181.862069
# South Boston Waterfront  254.855422
# South End                200.361963
# West End                 209.591837
# ...

# %%
df.plot(kind='bar')
#Conclusion -- This seems that the neighourhood group for the Boston city is not having the appropriate dataset
# price columns is having the NaN - Not A Number values to denote the missing values
# Out:
# <AxesSubplot:xlabel='neighbourhood_cleansed'>

# %% [markdown]
# # Conclusion ----
# In the initial Data Analysis we have found that the "Magnolia" is having the highest average price for the Seattle City whereas the "Leather District" is having the highest average price for the Boston City.
#
# Although,"Magnolia" average price per room is touching about the $160.
#
# #$250 in the "Leather District" in the Boston City.

# %%
Boston_Listings['price'].head()

#Converting the missing values to the zero in the Seattle Dataset
Seattle_Listings['price'] = Seattle_Listings['price'].fillna(0)
Seattle_Listings['price'].head()
# Out:
# 0    $250.00
# 1     $65.00
# 2     $65.00
# 3     $75.00
# 4     $79.00
# Name: price, dtype: object

# %%
#Plotting heatmap for the Boston City Neighbourhood 
import seaborn as sns

df_Boston_Listings_Heatmap = pd.DataFrame(Boston_Listings.groupby(['neighbourhood_cleansed'])['price'].mean())
sns.heatmap(df_Boston_Listings_Heatmap)
# Out:
# <AxesSubplot:ylabel='neighbourhood_cleansed'>

# %%
#Plotting heatmap for the Seattle City Neighbourhood 

df_Seattle_Listings_Heatmap = pd.DataFrame(Seattle_Listings.groupby(['neighbourhood_group_cleansed'])['price'].mean())
print(df_Seattle_Listings_Heatmap)

sns.heatmap(df_Seattle_Listings_Heatmap)
# Out:
#                                    price
# neighbourhood_group_cleansed
# Ballard                       115.986957
# Beacon Hill                    90.432203
# Capitol Hill                  115.425044
# Cascade                       116.505618
# Central Area                  111.265583
# Delridge                       76.949367
# Downtown                      141.009434
# Interbay                      109.727273
# Lake City                      88.194030
# Magnolia                      166.196721
# Northgate                      77.300000
# Other neighborhoods           104.741814
# Queen Anne                    134.850847
# Rainier Valley                 83.094340
# Seward Park                    97.113636
# University District            92.819672
# West Seattle                  125.103448
# <AxesSubplot:ylabel='neighbourhood_group_cleansed'>

# %%
ax = sns.countplot(y="property_type", hue="room_type", data=Seattle_Listings)

# %%
#Creating the subset dataframe based on the count of the roomtype ffor Seattle City

df_Seattle_RoomType_Count = pd.DataFrame(Seattle_Listings.groupby(['property_type'])['room_type'].count())
print(df_Seattle_RoomType_Count)
# Out:
#                  room_type
# property_type
# Apartment             1708
# Bed & Breakfast         37
# Boat                     8
# Bungalow                13
# Cabin                   21
# Camper/RV               13
# Chalet                   2
# Condominium             91
# Dorm                     2
# House                 1733
# Loft                    40
# Other                   22
# Tent                     5
# Townhouse              118
# Treehouse                3
# Yurt                     1

# %%
#Seaborn KDE Plot for Seattle Room Type based on the property type
sns.kdeplot(df_Seattle_RoomType_Count['room_type'])
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='Density'>

# %%
df_Seattle_RoomType_Count.columns
df_Seattle_RoomType_Count.describe
# Out:
# <bound method NDFrame.describe of                  room_type
# property_type
# Apartment             1708
# Bed & Breakfast         37
# Boat                     8
# Bungalow                13
# Cabin                   21
# Camper/RV               13
# Chalet                   2
# Condominium             91
# Dorm                     2
# House                 1733
# Loft                    40
# Other                   22
# Tent                     5
# Townhouse              118
# Treehouse                3
# Yurt                     1>

# %%
#Barplot based on the room type for Seattle Listings based upon the availability
sns.barplot(x=Seattle_Listings['room_type'], y=Seattle_Listings['availability_365']/100, data=Seattle_Listings)
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='availability_365'>

# %%
#Barplot based on the room type for Boston Listings based upon availability 

sns.barplot(x=Boston_Listings['room_type'], y=Boston_Listings['availability_365']/100, data=Boston_Listings)
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='availability_365'>
